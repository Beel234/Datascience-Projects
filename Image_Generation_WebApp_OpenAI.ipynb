# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 KB 1.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai: filename=openai-0.26.1-py3-none-any.whl size=67316 sha256=18146ddc2b1c123d2b11c249a0fba75ae8e8a3938d30a3ee07babcfac2bed986
#   Stored in directory: /root/.cache/pip/wheels/2f/9c/55/95d3609ccfc463eeffb96d50c756f1f1899453b85e92021a0a
# Successfully built openai
# ...

# %% [markdown]
# Task: generate an image by feeding the system a text/description
#
# import openai it is a Python code line that imports the OpenAI library.
#
# The urllib.request module in Python is part of the standard library and provides functions for opening and reading URLs (Uniform Resource Locators). The urllib.request module provides a set of simple and high-level APIs for handling HTTP and other network protocols.
#
# The from PIL import Image line of code is importing the Image module from the Python Imaging Library (PIL) package.
# PIL is a library that provides extensive support for opening, manipulating and saving many different image file formats.
# The from PIL import Image line of code is importing the Image module from the Python Imaging Library (PIL) package. PIL is a library that provides extensive support for opening, manipulating and saving many different image file formats.
#
#
# cv2 is a python library for the OpenCV (Open Source Computer Vision Library) which is an open-source library that includes several hundreds of computer vision algorithms. The library has more than 2500 optimized algorithms for Image Processing, Face Detection, Object Detection, Motion Analysis, Image Segmentation, and more. The library is written in C++, but it also has python bindings.
#
# The cv2 library allows you to perform various operations on images and videos, such as reading, writing, displaying, and processing images and videos, as well as detecting and tracking objects in images and videos.
#
# The import cv2 line is importing the openCV library so that you can use all the functions and methods provided by the library.
#
# The cv2 library is widely used in Computer Vision, Machine Learning, Robotics and Artificial Intelligence related projects. With the help of cv2 library, you can perform various image processing operations like reading, displaying, and writing images, face detection, object detection, object tracking, and many more.
#
#
# the code from google.colab.patches import cv2_imshow2 is used to import the cv2_imshow2 function from the google.colab.patches module in Colab environment, to display the image using OpenCV library.

# %%
import openai
import urllib.request #The image gotten from the api is in form of a url, so we need the url to get the image
from PIL import Image #to extract the image
import cv2
from google.colab.patches import cv2_imshow # to display the image

# %%
openai.api_key = "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" #Create a variable and paste your API key

# %%
img_response = openai.Image.create(
    prompt = 'an astronaut lounging in a tropical resort in space',
    n=1, #how many images do you want it to show
    size="512x512")    # 256x256, 512x512, 1024x1024 #the size of the messages

# %%
img_response
# Out:
# <OpenAIObject at 0x7fc901f7ee50> JSON: {
#   "created": 1673726390,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-R3LUXIGDcwMJS2N59xrb0b2X/user-TIPWe1X9WTOj29z1UGgiuEeP/img-YPrWlPgS7uMuNxeTn8UJWXWv.png?st=2023-01-14T18%3A59%3A50Z&se=2023-01-14T20%3A59%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-14T17%3A29%3A23Z&ske=2023-01-15T17%3A29%3A23Z&sks=b&skv=2021-08-06&sig=KLf2T/a0Fa117d7aed6ujkAqciJ5KGEGuXezN%2BZh2Dk%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url'] #the data is in json format to access the url which is the image, list
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-R3LUXIGDcwMJS2N59xrb0b2X/user-TIPWe1X9WTOj29z1UGgiuEeP/img-YPrWlPgS7uMuNxeTn8UJWXWv.png?st=2023-01-14T18%3A59%3A50Z&se=2023-01-14T20%3A59%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-14T17%3A29%3A23Z&ske=2023-01-15T17%3A29%3A23Z&sks=b&skv=2021-08-06&sig=KLf2T/a0Fa117d7aed6ujkAqciJ5KGEGuXezN%2BZh2Dk%3D'

# %%
img_url = img_response['data'][0]['url']
img_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-R3LUXIGDcwMJS2N59xrb0b2X/user-TIPWe1X9WTOj29z1UGgiuEeP/img-YPrWlPgS7uMuNxeTn8UJWXWv.png?st=2023-01-14T18%3A59%3A50Z&se=2023-01-14T20%3A59%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-14T17%3A29%3A23Z&ske=2023-01-15T17%3A29%3A23Z&sks=b&skv=2021-08-06&sig=KLf2T/a0Fa117d7aed6ujkAqciJ5KGEGuXezN%2BZh2Dk%3D'

# %%
urllib.request.urlretrieve(img_url, 'image.png')
# Out:
# ('image.png', <http.client.HTTPMessage at 0x7fc901f93520>)

# %%
img = cv2.imread("image.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FC917EF37F0>
